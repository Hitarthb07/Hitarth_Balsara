# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/BlackFriday (1).csv')

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %% [markdown]
# **Deleting column product category 2 and 3 as there are many rows which contains null values**

# %%
del df['Product_Category_2']
del df['Product_Category_3']

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %% [markdown]
# **2) Find mean of Product Category 1**

# %%
df['Product_Category_1'].mean()
# Out:
# 5.295546498455105

# %% [markdown]
# **3) Find unique and number of unique userid, product id, age group**

# %%
df['User_ID'].nunique()
# Out:
# 5891

# %%
df['Product_ID'].nunique()
# Out:
# 3623

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %% [markdown]
# **4) Give summary of Data Frame**

# %%
df.describe()
# Out:
#             User_ID    Occupation  Marital_Status  Product_Category_1  \
# count  5.375770e+05  537577.00000   537577.000000       537577.000000
# mean   1.002992e+06       8.08271        0.408797            5.295546
# std    1.714393e+03       6.52412        0.491612            3.750701
# min    1.000001e+06       0.00000        0.000000            1.000000
# 25%    1.001495e+06       2.00000        0.000000            1.000000
# 50%    1.003031e+06       7.00000        0.000000            5.000000
# 75%    1.004417e+06      14.00000        1.000000            8.000000
# max    1.006040e+06      20.00000        1.000000           18.000000
#
#             Purchase
# count  537577.000000
# mean     9333.859853
# std      4981.022133
# min       185.000000
# 25%      5866.000000
# 50%      8062.000000
# 75%     12073.000000
# max     23961.000000

# %% [markdown]
# **5) Find city Category, age group where number of purchase of product 1 is more than 15**

# %%
df[df['Product_Category_1'] > 15][['Age','City_Category']]
# Out:
#           Age City_Category
# 212     26-35             B
# 213     26-35             B
# 220     18-25             B
# 234     26-35             A
# 304     26-35             B
# ...       ...           ...
# 537457  36-45             A
# 537459  36-45             A
# 537468  36-45             C
# 537500  26-35             B
# 537540  26-35             B
#
# [13339 rows x 2 columns]

# %% [markdown]
# **6) Q4: Sort the DataFrame by Purchase in descending order, and display the top 3 records.**

# %%
df.sort_values(by = 'Purchase', ascending = False).nlargest(3, 'Purchase')
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 87440   1001474  P00052842      M  26-35           4             A
# 93016   1002272  P00052842      M  26-35           0             C
# 370891  1003160  P00052842      M  26-35          17             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 87440                           2               1                  10
# 93016                           1               0                  10
# 370891                          3               0                  10
#
#         Purchase
# 87440      23961
# 93016      23961
# 370891     23961

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %% [markdown]
# **7) print where Purchase is more than 10000 and City category is 'A'**

# %%
 df[(df['City_Category'].isin(['A'])) & (df['Purchase'] > 10000)]
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 1       1000001  P00248942      F   0-17          10             A
# 5       1000003  P00193542      M  26-35          15             A
# 13      1000005  P00145042      M  26-35          20             A
# 16      1000006   P0096642      F  51-55           9             A
# 56      1000015  P00334242      M  26-35           7             A
# ...         ...        ...    ...    ...         ...           ...
# 537457  1004725  P00327342      M  36-45           5             A
# 537459  1004725  P00250342      M  36-45           5             A
# 537557  1004736  P00175242      M  18-25          20             A
# 537562  1004736  P00146742      M  18-25          20             A
# 537570  1004736  P00162442      M  18-25          20             A
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 1                               2               0                   1
# ...

# %% [markdown]
# **8) Return columns of Gender, AGe, Occupation where Sta in current city is more than 2 Years**

# %%
df['Stay_In_Current_City_Years'] = pd.to_numeric(df['Stay_In_Current_City_Years'], errors='coerce')
df[df['Stay_In_Current_City_Years'] > 2][['Gender','Age', 'Occupation']]
# Out:
#        Gender    Age  Occupation
# 5           M  26-35          15
# 52          M  46-50           1
# 53          M  46-50           1
# 54          M  46-50           1
# 70          F  18-25           3
# ...       ...    ...         ...
# 537551      M  46-50           3
# 537552      M  46-50           3
# 537553      M  46-50           3
# 537554      M  46-50           3
# 537555      M  46-50           3
#
# [93312 rows x 3 columns]

# %% [markdown]
# **9) Plot a pie chart for Gender Column and show their Ratio**

# %%
gender_counts = df['Gender'].value_counts()

# %%
gender_counts.plot(kind = 'pie', y = 'Ratio', figsize = (6,6), autopct = '%.1f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# **10) Plot Bar graph for Gender Column**

# %%
df.groupby('Gender').size().plot(kind = 'bar', figsize = (6,6))
# Out:
# <Axes: xlabel='Gender'>

# %% [markdown]
# **11) Plot graph for Purcahse distribution by Age**

# %%
df.groupby('Age').size().plot(kind = 'bar', figsize = (12,6), title = 'Purchase Distribution by Age')
# Out:
# <Axes: title={'center': 'Purchase Distribution by Age'}, xlabel='Age'>

# %% [markdown]
# **12) Plot pie chat between Age group and amount of purchase that they have made**

# %%
df.groupby('Age')['Purchase'].sum().plot(kind = 'pie', autopct = '%0.1f')
# Out:
# <Axes: ylabel='Purchase'>

# %% [markdown]
# **13) Plot bar graph between Age and Gender using Seaborn Library**

# %%
sns.countplot(x = 'Age', hue = 'Gender', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x = 'Gender', hue = 'Age', data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %% [markdown]
# **14) FInd the mean of Purcahse where Occuption is 10**

# %%
df[df['Occupation'] == 10].agg({'Purchase': 'mean'})
# Out:
# Purchase    9052.83641
# dtype: float64

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#    Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                         2.0               0                   3      8370
# 1                         2.0               0                   1     15200
# 2                         2.0               0                  12      1422
# 3                         2.0               0                  12      1057
# 4                         NaN               0                   8      7969

# %% [markdown]
# **15) filter occupation where purcahse is in the range of 10000-20000 and display their Occupation and City Category**

# %%
df[df['Purchase'].between(10000,20000)][['Occupation','City_Category']].head()
# Out:
#    Occupation City_Category
# 1          10             A
# 5          15             A
# 6           7             B
# 7           7             B
# 8           7             B
